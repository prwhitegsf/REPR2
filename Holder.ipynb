# %%
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.metrics import RocCurveDisplay, auc
from sklearn.model_selection import StratifiedKFold

n_splits = 6
cv = StratifiedKFold(n_splits=n_splits)
classifier = model#svm.SVC(kernel="linear", probability=True, random_state=random_state)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots(figsize=(6, 6))
for fold, (train, test) in enumerate(cv.split(feature_train, label_train)):
    classifier.fit(feature_train[train], label_train[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        feature_train[test],
        label_train[test],
        name=f"ROC fold {fold}",
        alpha=0.3,
        lw=1,
        ax=ax,
        plot_chance_level=(fold == n_splits - 1),
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title=f"Mean ROC curve with variability\n(Positive label = angry)",
)
ax.legend(loc="lower right")
plt.show()

# %%
# implement simple widget test

with plt.ioff():
    plt.close()
    
fig, ax = plt.subplots( figsize=(3,3),layout="tight",num=None)
    
ax.set_title("Kernel Boxplot")

  
    
fig.canvas.header_visible = False

fig.canvas.toolbar_position = 'bottom'
ax.grid(True)    
line = ax.boxplot(bx.describe(),positions=[2,4,6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,tick_labels=['rbf','linear','poly'],
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

# %%
from sklearn.model_selection import ValidationCurveDisplay
ValidationCurveDisplay.from_estimator(
   SVC(kernel="rbf"), feature_train, label_train, param_name="gamma", param_range=np.logspace(-7, 3, 10)
)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

classifier = make_pipeline(SVC(gamma='auto',kernel='rbf'))
classifier.fit(feature_train, label_train)

from sklearn.metrics import PrecisionRecallDisplay

display = PrecisionRecallDisplay.from_estimator(
    classifier, feature_test, label_test, name="SVC", plot_chance_level=True
)
_ = display.ax_.set_title("2-class Precision-Recall curve")

# %%
plt.ioff() 
        fig = plt.figure(figsize=(4,6), layout="constrained")
        
        axs = fig.subplot_mosaic(
            """
            AAA
            AAA
            BBB
            BBB
            
            """)
        
        axs["A"].set_title("ROC Curve")
        RocCurveDisplay.from_estimator(self.model, self.features, self.labels,ax=axs["A"],name="ROC",pos_label=1)
